# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib_fontja
import pandas as pd

# %%
x = np.arange(0,8,1)
y = 7*x-3
plt.figure(figsize=(5,8))
plt.plot(x,y,alpha=0.5)
plt.plot(x[1:],y[1:],'o',alpha=1)
plt.ylim(-3,48)
plt.xlim(0,7.5)
# Out:
# (0.0, 7.5)
